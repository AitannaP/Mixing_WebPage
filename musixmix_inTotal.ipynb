# %%
#DJMixingAPP/get_token.py
import requests

# Replace with your actual client id and secret
client_id = "8bba093121064231a91f19d7ec70757b"
client_secret = "899584a8168442cda47824803bfde729"

# Endpoint for Spotify token access
token_url = "https://accounts.spotify.com/api/token"

# Request body parameters
payload = {
    "grant_type": "client_credentials",
    "client_id": client_id,
    "client_secret": client_secret,
}

# Set headers for content type
headers = {
    "Content-Type": "application/x-www-form-urlencoded",
}

# Send POST request for access token
response = requests.post(token_url, headers=headers, data=payload)

# Check for successful response (200 OK)
if response.status_code == 200:
    # Parse the JSON response to get access token
    data = response.json()
    access_token = data["access_token"]
    print("Successfully obtained access token:", access_token)
    
    # Use the access token for further Spotify API calls here...
    
else:
    print("Error obtaining access token:", response.status_code, response.text)
# Out:
# Successfully obtained access token: BQAFY5rZBBynJRhJsOk2_JyccYbkuP6C0S0C5fnXBmKxZjZ1Dg3FFSyjoOYILV6OKiQHqR0aNo4eGQq1pGDhmdZGae7bEyWXMwETFCm0oJ4-QiiFVuI

# %%
#DJMixingAPP/pull_search_song_audio_analysis_data_copy.py
import requests 

secret = '899584a8168442cda47824803bfde729'
client_id = '8bba093121064231a91f19d7ec70757b'
api_auth = 'https://accounts.spotify.com/api/token'
album_url = 'https://api.spotify.com/v1/albums/'
search_url = 'https://api.spotify.com/v1/search?q=chromakopia&type=album'
track_url = "https://api.spotify.com/v1/me/shows?offset=0&limit=20"
# token= "BQBjdkYKGTVpZPHzCI0zbSo4FMUu4mulz7deyZgqJ0ITSBcjDe1VwzWd-dJYl3ySvx3ao9GrNclTzX2trY8Gggw0sSzy4mY_YYTLSb-qC4l3lyjhnco"
single = 'https://api.spotify.com/v1/audio-analysis/11dFghVXANMlKmJXsNCbNl' # with key and tempo
token= access_token
headers = {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'secret': secret
}

h = {
    'Authorization': f'Bearer {token}' 
}
session = requests.Session()
search_res = session.get(single, headers=h)
# response = session.post(api_auth, headers=headers)

result = search_res.text
print(result)

#save in file

# Open the file in write mode ('w')
with open("output_search_song.json", "w") as f:
    # Write the result to the file
    f.write(result)
# Out:
# {"meta":{"analyzer_version":"4.0.0","platform":"Linux","detailed_status":"OK","status_code":0,"timestamp":1495193577,"analysis_time":6.93906,"input_process":"libvorbisfile L+R 44100->22050"},"track":{"num_samples":4585515,"duration":207.95985,"sample_md5":"","offset_seconds":0,"window_seconds":0,"analysis_sample_rate":22050,"analysis_channels":1,"end_of_fade_in":0.0,"start_of_fade_out":201.13705,"loudness":-2.743,"tempo":114.944,"tempo_confidence":0.74,"time_signature":4,"time_signature_confidence":0.994,"key":2,"key_confidence":0.408,"mode":1,"mode_confidence":0.485,"codestring":"eJxVmgl2LDcOBK_SR-C-3P9ijki2vuSZZ1tkVbO4AIlMgLOPdWaZn_LZd_H_u-enzfWZfczSxx6fccqnz1v7uOt8dl-fs-Zo9OzPKTwb_d7Ji_c2Xtzz0ns_tbbyqaWtW2b-bHV91jxj3nt43Gv7jD5PaWXtT12MtGiutkb_1N3OZ87Z616L5mkM75Nxa_k0xv7UO2-_Z-5Pa6MwVGtlrHk_rTNNPlx7v2N92spv-Wrr43zann53ldV7u59eyvmcWc-6fO5DF8ubjbdWpdlvJnldPStd52eSh_n1w2_rWo2ZsIR-2RpaPB2dCVV-6xLGKD3z819zl-r8xnAupezS3f2xy3Aaq99dK1ve-W1hIHag8tc5Nu9k__ir70zyHg7Db_Db0RmhLF_ei5nuwonUNj_8gA
# ...

# %%
# DJMixingAPP/pull_search_song_data.py
# pull data from spotify (one song)
#search for single based onSpotify ID

import requests 

secret = '899584a8168442cda47824803bfde729'
client_id = '8bba093121064231a91f19d7ec70757b'
api_auth = 'https://accounts.spotify.com/api/token'
album_url = 'https://api.spotify.com/v1/albums/'
search_url = 'https://api.spotify.com/v1/search?q=chromakopia&type=album'
track_url = "https://api.spotify.com/v1/me/shows?offset=0&limit=20"
# token= "BQDztByOAgzY067IbRiZf4xDZJuUOWlf3pCXbAl4OJWZ3K3gTk1OGHk7q0f-VvrW571viRcmv3lHpq1OT-ufI2TnQ1Z-LzP_WeovNDyb-6W9J9tFjz4"
single = 'https://api.spotify.com/v1/audio-analysis/11dFghVXANMlKmJXsNCbNl' # with key and tempo

headers = {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'secret': secret
}

h = {
    'Authorization': f'Bearer {token}' 
}
session = requests.Session()
search_res = session.get(single, headers=h)
# response = session.post(api_auth, headers=headers)

result = search_res.text
print(result)

#save in file

# Open the file in write mode ('w')
with open("output_audio_analysis.json", "w") as f:
    # Write the result to the file
    f.write(result)



# curl --request GET \
#   --url https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl \
#   --header 'Authorization: Bearer BQCr7_EKzasodZSpt96CB92vZD6IEIMOwpBeqSMmHSXCU1bqFFqYm9zQ0tpLEcpTbvoR7HQZqLXdlDSdG8NEV8eDWiE8weiWj--9QihjOHGtVRIklTY'
# Out:
# {"meta":{"analyzer_version":"4.0.0","platform":"Linux","detailed_status":"OK","status_code":0,"timestamp":1495193577,"analysis_time":6.93906,"input_process":"libvorbisfile L+R 44100->22050"},"track":{"num_samples":4585515,"duration":207.95985,"sample_md5":"","offset_seconds":0,"window_seconds":0,"analysis_sample_rate":22050,"analysis_channels":1,"end_of_fade_in":0.0,"start_of_fade_out":201.13705,"loudness":-2.743,"tempo":114.944,"tempo_confidence":0.74,"time_signature":4,"time_signature_confidence":0.994,"key":2,"key_confidence":0.408,"mode":1,"mode_confidence":0.485,"codestring":"eJxVmgl2LDcOBK_SR-C-3P9ijki2vuSZZ1tkVbO4AIlMgLOPdWaZn_LZd_H_u-enzfWZfczSxx6fccqnz1v7uOt8dl-fs-Zo9OzPKTwb_d7Ji_c2Xtzz0ns_tbbyqaWtW2b-bHV91jxj3nt43Gv7jD5PaWXtT12MtGiutkb_1N3OZ87Z616L5mkM75Nxa_k0xv7UO2-_Z-5Pa6MwVGtlrHk_rTNNPlx7v2N92spv-Wrr43zann53ldV7u59eyvmcWc-6fO5DF8ubjbdWpdlvJnldPStd52eSh_n1w2_rWo2ZsIR-2RpaPB2dCVV-6xLGKD3z819zl-r8xnAupezS3f2xy3Aaq99dK1ve-W1hIHag8tc5Nu9k__ir70zyHg7Db_Db0RmhLF_ei5nuwonUNj_8gA
# ...

# %%
#DJMixingAPP/convert_json_csv.py
import json
import csv

# Open the JSON file
with open('output_search_song.json', 'r') as f:
  data = json.load(f)

# from data[track], you want, duration ,tempo, key , mode, time signature, loudness
#from data[bars], duration of each bar (will be a lot but needed later)
# from data[sections], you can get length of earch secion and the tempo for  seconds

# Extract relevant data from the JSON object (modify as needed)
track_total = data['track']
track_data = []


# Extract relevant data
duration = track_total['duration']
tempo = track_total['tempo']
key = track_total['key']
mode = track_total['mode']
time_signature = track_total['time_signature']

# Create a list of CSV rows
csv_rows = [
  ["Duration", duration],
  ["Tempo", tempo],
  ["Key", key],
  ["Mode", mode],
  ["Time_signature", time_signature],
]


# Write data to CSV file
with open("spotify_data.csv", "w", newline="") as csvfile:
  writer = csv.writer(csvfile)
  writer.writerows(csv_rows)

print("Converted data to CSV file: spotify_data.csv")
# Out:
# Converted data to CSV file: spotify_data.csv

# %%
# #DJMixingAPP/conver_single_track_csv.py
# import json
# import csv

# # Open the JSON file
# with open('output_search_song.json', 'r') as f:
#   data = json.load(f)

# # Extract relevant data
# album_name = data["album"]["name"]
# artist_name = data["artists"][0]["name"]
# release_date = data["album"]["release_date"]
# track_count = data["album"]["total_tracks"]

# # Create a list of CSV rows
# csv_rows = [
#   ["Album Name", album_name],
#   ["Artist Name", artist_name],
#   ["Release Date", release_date],
#   ["Track Count", track_count],
# ]

# # Write data to CSV file
# with open("spotify_data.csv", "w", newline="") as csvfile:
#   writer = csv.writer(csvfile)
#   writer.writerows(csv_rows)

# print("Converted data to CSV file: spotify_data_single.csv")

# %%
data
# Out:
# {'meta': {'analyzer_version': '4.0.0',
#   'platform': 'Linux',
#   'detailed_status': 'OK',
#   'status_code': 0,
#   'timestamp': 1495193577,
#   'analysis_time': 6.93906,
#   'input_process': 'libvorbisfile L+R 44100->22050'},
#  'track': {'num_samples': 4585515,
#   'duration': 207.95985,
#   'sample_md5': '',
#   'offset_seconds': 0,
#   'window_seconds': 0,
#   'analysis_sample_rate': 22050,
#   'analysis_channels': 1,
#   'end_of_fade_in': 0.0,
#   'start_of_fade_out': 201.13705,
#   'loudness': -2.743,
#   'tempo': 114.944,
#   'tempo_confidence': 0.74,
#   'time_signature': 4,
#   'time_signature_confidence': 0.994,
#   'key': 2,
#   'key_confidence': 0.408,
#   'mode': 1,
#   'mode_confidence': 0.485,
# ...

# %%
#DJMixingAPP/temp_tests/copy/convert_json_csv_copy.py
import json
import csv

# Open the JSON file
with open('output_search_song.json', 'r') as f:
  data = json.load(f)

# from data[track], you want, duration ,tempo, key , mode, time signature, loudness
#from data[bars], duration of each bar (will be a lot but needed later)
# from data[sections], you can get length of earch secion and the tempo for  seconds

# Extract relevant data from the JSON object (modify as needed)
track_total = data['track']
track_data = []


# Extract relevant data
duration = track_total['duration']
tempo = track_total['tempo']
key = track_total['key']
mode = track_total['mode']
time_signature = track_total['time_signature']

# Create a list of CSV rows
csv_rows = [
  ["Duration", duration],
  ["Tempo", tempo],
  ["Key", key],
  ["Mode", mode],
  ["Time_signature", time_signature],
]


# Write data to CSV file
with open("spotify_converted_data.csv", "w", newline="") as csvfile:
  writer = csv.writer(csvfile)
  writer.writerows(csv_rows)

print("Converted data to CSV file: spotify_converted_data.csv")
# Out:
# Converted data to CSV file: spotify_converted_data.csv

# %%
# DJMixingAPP/temp_tests/copy/pull_search_song_key_tempo_data_copy.py
#pull data from spotify (one song)
#search for single based onSpotify ID

import requests 

secret = '899584a8168442cda47824803bfde729'
client_id = '8bba093121064231a91f19d7ec70757b'
api_auth = 'https://accounts.spotify.com/api/token'
album_url = 'https://api.spotify.com/v1/albums/'
search_url = 'https://api.spotify.com/v1/search?q=chromakopia&type=album'
track_url = "https://api.spotify.com/v1/me/shows?offset=0&limit=20"
# token= "BQCr7_EKzasodZSpt96CB92vZD6IEIMOwpBeqSMmHSXCU1bqFFqYm9zQ0tpLEcpTbvoR7HQZqLXdlDSdG8NEV8eDWiE8weiWj--9QihjOHGtVRIklTY"
single = 'https://api.spotify.com/v1/audio-analysis/11dFghVXANMlKmJXsNCbNl' # with key and tempo

headers = {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'secret': secret
}

h = {
    'Authorization': f'Bearer {token}' 
}
session = requests.Session()
search_res = session.get(single, headers=h)
# response = session.post(api_auth, headers=headers)

result = search_res.text
print(result)

#save in file

# Open the file in write mode ('w')
with open("output_pull_search_song_key_tempo_data.json", "w") as f:
    # Write the result to the file
    f.write(result)



# curl --request GET \
#   --url https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl \
#   --header 'Authorization: Bearer BQCr7_EKzasodZSpt96CB92vZD6IEIMOwpBeqSMmHSXCU1bqFFqYm9zQ0tpLEcpTbvoR7HQZqLXdlDSdG8NEV8eDWiE8weiWj--9QihjOHGtVRIklTY'
# Out:
# {"meta":{"analyzer_version":"4.0.0","platform":"Linux","detailed_status":"OK","status_code":0,"timestamp":1495193577,"analysis_time":6.93906,"input_process":"libvorbisfile L+R 44100->22050"},"track":{"num_samples":4585515,"duration":207.95985,"sample_md5":"","offset_seconds":0,"window_seconds":0,"analysis_sample_rate":22050,"analysis_channels":1,"end_of_fade_in":0.0,"start_of_fade_out":201.13705,"loudness":-2.743,"tempo":114.944,"tempo_confidence":0.74,"time_signature":4,"time_signature_confidence":0.994,"key":2,"key_confidence":0.408,"mode":1,"mode_confidence":0.485,"codestring":"eJxVmgl2LDcOBK_SR-C-3P9ijki2vuSZZ1tkVbO4AIlMgLOPdWaZn_LZd_H_u-enzfWZfczSxx6fccqnz1v7uOt8dl-fs-Zo9OzPKTwb_d7Ji_c2Xtzz0ns_tbbyqaWtW2b-bHV91jxj3nt43Gv7jD5PaWXtT12MtGiutkb_1N3OZ87Z616L5mkM75Nxa_k0xv7UO2-_Z-5Pa6MwVGtlrHk_rTNNPlx7v2N92spv-Wrr43zann53ldV7u59eyvmcWc-6fO5DF8ubjbdWpdlvJnldPStd52eSh_n1w2_rWo2ZsIR-2RpaPB2dCVV-6xLGKD3z819zl-r8xnAupezS3f2xy3Aaq99dK1ve-W1hIHag8tc5Nu9k__ir70zyHg7Db_Db0RmhLF_ei5nuwonUNj_8gA
# ...

# %%
# DJMixingAPP/temp_tests/copy/convert_json_csv_copy.py
import json
import csv

# Open the JSON file
with open('output_search_song.json', 'r') as f:
  data = json.load(f)

# from data[track], you want, duration ,tempo, key , mode, time signature, loudness
#from data[bars], duration of each bar (will be a lot but needed later)
# from data[sections], you can get length of earch secion and the tempo for  seconds

# Extract relevant data from the JSON object (modify as needed)
track_total = data['track']
track_data = []


# Extract relevant data
duration = track_total['duration']
tempo = track_total['tempo']
key = track_total['key']
mode = track_total['mode']
time_signature = track_total['time_signature']

# Create a list of CSV rows
csv_rows = [
  ["Duration", duration],
  ["Tempo", tempo],
  ["Key", key],
  ["Mode", mode],
  ["Time_signature", time_signature],
]


# Write data to CSV file
with open("csv_convert_json_csv_copy.csv", "w", newline="") as csvfile:
  writer = csv.writer(csvfile)
  writer.writerows(csv_rows)

print("Converted data to CSV file: csv_convert_json.csv")
# Out:
# Converted data to CSV file: csv_convert_json.csv

# %%
#populate camelot wheel

camelot_wheel={}
k= camelot_wheel

for i in range(1,13):
    for j in ['a','b']:
        temp = str(i)+j
        if '1' in temp:
            x = '12'
            y = '2'
                        #a                                                                  #b
            k[temp] = [ '1a' + ', ' + (y+'a') + ', ' + (x+'a') ] +  ['1b' + ', ' + (y+'b') + ', ' + (x+'b') ] 
        elif '12' in temp:
            x = 11
            y = 1
                        #a                                                                  #b
            k[temp] = [ '12a' + ', ' + (y+'a') + ', ' + (x+'a') ] +  ['12b' + 'b' + ', ' + (y+'b') + ', ' + (x+'b') ] 
        elif 'a' in temp:
            x =  str(int(temp[0]) +1)
            y =  str(int(temp[0]) -1)
                        #a                                                                  #b
            k[temp] = [ temp[0] +'a'+ ', ' + (y+'a') + ', ' + (x+'a') ] +  [temp[0] + 'b' + ', ' + (y+'b') + ', ' + (x+'b') ] 
        elif 'b' in temp:
            x =  str(int(temp[0]) +1)
            y =  str(int(temp[0]) -1)
                        #b                                                                  #a
            k[temp] = [temp[0] + 'b' + ', ' + (y+'b') + ', ' + (x+'b')  ]  + [ temp[0] +'a' + ', ' + (y+'b') + ', ' + (x+'a') ] 




            camelot_wheel = k

# %%
camelot_wheel['1a']
# Out:
# ['1a, 2a, 12a', '1b, 2b, 12b']

# %%
camelot_wheel_key = {
    (0, 0): "C Minor",
    (1, 0): "C# Minor",
    (2, 0): "D Minor",
    (3, 0): "D# Minor",
    (4, 0): "E Minor",
    (5, 0): "F Minor",
    (6, 0): "F# Minor",
    (7, 0): "G Minor",
    (8, 0): "G# Minor",
    (9, 0): "A Minor",
    (10, 0): "A# Minor",
    (11, 0): "B Minor",
    (0, 1): "C Major",
    (1, 1): "C# Major",
    (2, 1): "D Major",
    (3, 1): "D# Major",
    (4, 1): "E Major",
    (5, 1): "F Major",
    (6, 1): "F# Major",
    (7, 1): "G Major",
    (8, 1): "G# Major",
    (9, 1): "A Major",
    (10, 1): "A# Major",
    (11, 1): "B Major"
}

# %%
#take from  csv_convert_json.csv and print reference of camelot wheel

single_song_data = {}

with open('csv_convert_json_csv_copy.csv', 'r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        single_song_data[row[0]] = row[1]
        print(row)
# Out:
# ['Duration', '207.95985']
# ['Tempo', '114.944']
# ['Key', '2']
# ['Mode', '1']
# ['Time_signature', '4']

# %%
single_song_data['Duration']
# Out:
# '207.95985'

# %%
camelot_wheel_reference = {
    (0, 0):  '5a', #"C Minor",
    (1, 0): '12a', #"C# Minor"
    (2, 0): '7a', #"D Minor", 
    (3, 0): '2a', #"D# Minor", 
    (4, 0): '9a', #"E Minor", 
    (5, 0): '4a', #"F Minor", 
    (6, 0): '11a', #"F# Minor", 
    (7, 0): '6a', #"G Minor", 
    (8, 0): '1a', #"G# Minor", 
    (9, 0): '8a', #"A Minor", 
    (10, 0): '3a', #"A# Minor", 
    (11, 0): '10a', #"B Minor", 
    (0, 1): '8b', #"C Major", 
    (1, 1): '3b', #"C# Major", 
    (2, 1): '10b', #"D Major", 
    (3, 1): '5b', #"D# Major", 
    (4, 1): '12b',#"E Major", 
    (5, 1): '7b', #"F Major", 
    (6, 1): '2b', #"F# Major", 
    (7, 1): '9b', #"G Major", 
    (8, 1): '9b', #"G# Major", 
    (9, 1): '11b', #"A Major", 
    (10, 1): '6b', #"A# Major", 
    (11, 1): '1b', #"B Major"
    }

camelot_wheel_reference[(0,0)]
# Out:
# '5a'

# %%
single_camelot_wheel = camelot_wheel_reference[(int(single_song_data['Key']),int(single_song_data['Mode']))]
single_camelot_wheel
# Out:
# '10b'

# %%
camelot_wheel[single_camelot_wheel]
# Out:
# ['1a, 2a, 12a', '1b, 2b, 12b']

# %%
#find a list of songs with single song tempo and the keys in this track

import csv
import requests 

secret = '899584a8168442cda47824803bfde729'
client_id = '8bba093121064231a91f19d7ec70757b'
api_auth = 'https://accounts.spotify.com/api/token'
album_url = 'https://api.spotify.com/v1/albums/'
search_url = 'https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album'
track_url = "https://api.spotify.com/v1/me/shows?offset=0&limit=20"
# token= "BQBjdkYKGTVpZPHzCI0zbSo4FMUu4mulz7deyZgqJ0ITSBcjDe1VwzWd-dJYl3ySvx3ao9GrNclTzX2trY8Gggw0sSzy4mY_YYTLSb-qC4l3lyjhnco"
single = 'https://api.spotify.com/v1/audio-analysis/11dFghVXANMlKmJXsNCbNl' # with key and tempo
token= access_token
get_reccomendations = 'https://api.spotify.com/v1/recommendations?seed_artists=4NHQUGzhtTLFvgF5SZesLK&seed_genres=rnb&seed_tracks=0c6xIDDpzE81m2q797ordA&min_key=0&max_key=3&min_tempo=132&max_tempo=140&target_time_signature=4'
headers = {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'secret': secret
}

h = {
    'Authorization': f'Bearer {token}' 
}
session = requests.Session()
search_res = session.get(get_reccomendations, headers=h)
# response = session.post(api_auth, headers=headers)

result = search_res.text
print(result)

#save in file

# Open the file in write mode ('w')
with open("json_search_list_output.json", "w") as f:
    # Write the result to the file
    f.write(result)
# Out:
# {
#   "tracks" : [ {
#     "album" : {
#       "album_type" : "ALBUM",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI"
#         },
#         "href" : "https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI",
#         "id" : "2wY79sveU1sp5g7SokKOiI",
#         "name" : "Sam Smith",
#         "type" : "artist",
#         "uri" : "spotify:artist:2wY79sveU1sp5g7SokKOiI"
#       } ],
#       "available_markets" : [ "AU" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/6oSJciY7B2HlZPJpyR9nOR"
#       },
#       "href" : "https://api.spotify.com/v1/albums/6oSJciY7B2HlZPJpyR9nOR",
#       "id" : "6oSJciY7B2HlZPJpyR9nOR",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b273aeca5ce27cb0041319cbb734",
#         "width" : 640
#       }, {
#         "height" : 300,
# ...

# %%
# read json_search_list_output.json into a csv file

import json
import csv

# Open the JSON file
with open('json_search_list_output.json', 'r') as f:
  data = json.load(f)

# # Extract relevant data
# album_name = data['tracks']["album"]["name"]
# artist_name = data["artists"][0]["name"]
# release_date = data["album"]["release_date"]
# track_count = data["album"]["total_tracks"]

# # Create a list of CSV rows
# csv_rows = [
#   ["Album Name", album_name],
#   ["Artist Name", artist_name],
#   ["Release Date", release_date],
#   ["Track Count", track_count],
# ]

# # Write data to CSV file
# with open("csv_search_list_output.csv", "w", newline="") as csvfile:
#   writer = csv.writer(csvfile)
#   writer.writerows(csv_rows)

# print("Converted data to CSV file: spotify_data_single.csv")

# %%
# data['tracks'][0]['album']['artists'][0]['name'] #artist name 1
# data['tracks'][0]['album']['artists'][1]['name'] #artist name 2
# song_id = data['tracks'][0]['album']['artists'][1]['id'] #song id
# data['tracks'][0]['name'] #song name
# data['tracks'][1] # next song

# %%
song_id = data['tracks'][0]['album']['artists'][0]['id'] #song id
song_id
# Out:
# '2wY79sveU1sp5g7SokKOiI'

# %%
data['tracks'][0]
# Out:
# {'album': {'album_type': 'ALBUM',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#     'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#     'id': '2wY79sveU1sp5g7SokKOiI',
#     'name': 'Sam Smith',
#     'type': 'artist',
#     'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'}],
#   'available_markets': ['AU'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6oSJciY7B2HlZPJpyR9nOR'},
#   'href': 'https://api.spotify.com/v1/albums/6oSJciY7B2HlZPJpyR9nOR',
#   'id': '6oSJciY7B2HlZPJpyR9nOR',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273aeca5ce27cb0041319cbb734',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02aeca5ce27cb0041319cbb734',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851aeca5ce27cb0041319cbb734',
#     'width': 64}],
# ...

# %%
data['tracks'][0]['id']
# Out:
# '15HsdLcI9txtlLpsHBbEjn'

# %%
data['tracks'][0]
# Out:
# {'album': {'album_type': 'ALBUM',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#     'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#     'id': '2wY79sveU1sp5g7SokKOiI',
#     'name': 'Sam Smith',
#     'type': 'artist',
#     'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'}],
#   'available_markets': ['AU'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6oSJciY7B2HlZPJpyR9nOR'},
#   'href': 'https://api.spotify.com/v1/albums/6oSJciY7B2HlZPJpyR9nOR',
#   'id': '6oSJciY7B2HlZPJpyR9nOR',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273aeca5ce27cb0041319cbb734',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02aeca5ce27cb0041319cbb734',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851aeca5ce27cb0041319cbb734',
#     'width': 64}],
# ...

# %%
#search song id
song_id = data['tracks'][0]['id']

get_track = 'https://api.spotify.com/v1/tracks/{song_id}'


# get_reccomendations = 'https://api.spotify.com/v1/recommendations?seed_artists=4NHQUGzhtTLFvgF5SZesLK&seed_genres=rnb&seed_tracks=0c6xIDDpzE81m2q797ordA&min_key=0&max_key=3&min_tempo=132&max_tempo=140&target_time_signature=4'
headers = {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'secret': secret
}

h = {
    'Authorization': f'Bearer {token}' 
}
session = requests.Session()
search_res = session.get(get_track, headers=h)
# response = session.post(api_auth, headers=headers)

result = search_res.text
print(result)

#save in file

# Open the file in write mode ('w')
with open("json_list_of_songs.json", "w") as f:
    # Write the result to the file
    f.write(result)



#find the correct spotify id to use
# Out:
# {"error": {"status": 400, "message": "Invalid base62 id" } }

# %%
#print me a list wirh criteria in the camelot wheel 


#check vibe of song, check nearest 


#output in on web page
